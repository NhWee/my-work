# %% [markdown]
# # Starter Notebook
#
# This notebook uses the local `.venv` Python environment.

# %%
import numpy as np
import pandas as pd

values = np.array([1, 2, 3, 4, 5])
pd.DataFrame({
    "metric": ["count", "mean", "std"],
    "value": [values.size, values.mean(), values.std()],
})
